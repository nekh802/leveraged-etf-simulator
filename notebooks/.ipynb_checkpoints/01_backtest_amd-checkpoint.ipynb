# %%
import certifi, os

# %%
os.environ["SSL_CERT_FILE"] = certifi.where()

# %%
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# %%
import sys

# %%
from pathlib import Path

# %%
PROJECT_ROOT = Path().resolve().parent

# %%
sys.path.append(str(PROJECT_ROOT / "src"))

# %%
sys.executable
# Out:
# 'C:\\Users\\ceres\\OneDrive\\문서\\coding\\leveraged-etf-simulator\\.venv\\Scripts\\python.exe'

# %%
from fetch_data import fetch_prices

# %%
prices = fetch_prices("AMD")
# Out:
# Failed to get ticker 'AMD' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: C:\Users\ceres\OneDrive\문서\coding\leveraged-etf-simulator\.venv\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMD']: SSLError('Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: C:\\Users\\ceres\\OneDrive\\문서\\coding\\leveraged-etf-simulator\\.venv\\Lib\\site-packages\\certifi\\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')

# %%
prices.head()
# Out:
# Empty DataFrame
# Columns: [(Adj Close, AMD), (Close, AMD), (High, AMD), (Low, AMD), (Open, AMD), (Volume, AMD)]
# Index: []
